# %%
# 파일목록을 불러와 file_list에 저장하기 
import os
file_list = os.listdir('FloorPlan')
file_list
# Out:
# ['fp_004.jpg',
#  'fp_010.jpg',
#  'fp_038.jpg',
#  'fp_206.jpg',
#  'fp_212.jpg',
#  'fp_372.jpg',
#  'fp_414.jpg',
#  'fp_400.jpg',
#  'fp_366.jpg',
#  'fp_428.jpg',
#  'fp_399.jpg',
#  'fp_170.jpg',
#  'fp_164.jpg',
#  'fp_158.jpg',
#  'fp_159.jpg',
#  'fp_165.jpg',
#  'fp_171.jpg',
#  'fp_398.jpg',
#  'fp_429.jpg',
#  'fp_401.jpg',
#  'fp_367.jpg',
#  'fp_373.jpg',
#  'fp_415.jpg',
#  'fp_213.jpg',
#  'fp_207.jpg',
#  'fp_039.jpg',
#  'fp_011.jpg',
#  'fp_005.jpg',
#  'fp_013.jpg',
#  'fp_007.jpg',
#  'fp_211.jpg',
#  'fp_205.jpg',
#  'fp_239.jpg',
#  'fp_365.jpg',
#  'fp_403.jpg',
#  'fp_417.jpg',
#  'fp_371.jpg',
#  'fp_359.jpg',
#  'fp_167.jpg',
#  'fp_173.jpg',
#  'fp_198.jpg',
#  'fp_199.jpg',
#  'fp_172.jpg',
#  'fp_166.jpg',
#  'fp_358.jpg',
#  'fp_416.jpg',
#  'fp_370.jpg',
#  'fp_364.jpg',
#  'fp_402.jpg',
#  'fp_238.jpg',
#  'fp_204.jpg',
#  'fp_210.jpg',
#  'fp_006.jpg',
#  'fp_012.jpg',
#  'fp_016.jpg',
#  'fp_002.jpg',
#  'fp_228.jpg',
#  'fp_214.jpg',
#  'fp_200.jpg',
#  'fp_348.jpg',
#  'fp_406.jpg',
#  'fp_360.jpg',
#  'fp_374.jpg',
#  'fp_412.jpg',
#  'fp_162.jpg',
#  'fp_176.jpg',
#  'fp_189.jpg',
#  'fp_188.jpg',
#  'fp_177.jpg',
#  'fp_163.jpg',
#  'fp_375.jpg',
#  'fp_413.jpg',
#  'fp_407.jpg',
#  'fp_361.jpg',
#  'fp_349.jpg',
#  'fp_201.jpg',
#  'fp_215.jpg',
#  'fp_229.jpg',
#  'fp_003.jpg',
#  'fp_017.jpg',
#  'fp_029.jpg',
#  'fp_001.jpg',
#  'fp_015.jpg',
#  'fp_203.jpg',
#  'fp_217.jpg',
#  'fp_439.jpg',
#  'fp_411.jpg',
#  'fp_377.jpg',
#  'fp_363.jpg',
#  'fp_405.jpg',
#  'fp_388.jpg',
#  'fp_149.jpg',
#  'fp_175.jpg',
#  'fp_161.jpg',
#  'fp_160.jpg',
#  'fp_174.jpg',
#  'fp_148.jpg',
#  'fp_389.jpg',
#  'fp_362.jpg',
#  'fp_404.jpg',
#  'fp_410.jpg',
#  'fp_376.jpg',
#  'fp_438.jpg',
#  'fp_216.jpg',
#  'fp_202.jpg',
#  'fp_014.jpg',
#  'fp_000.jpg',
#  'fp_028.jpg',
#  'fp_067.jpg',
#  'fp_073.jpg',
#  'fp_098.jpg',
#  'fp_265.jpg',
#  'fp_271.jpg',
#  'fp_259.jpg',
#  'fp_477.jpg',
#  'fp_311.jpg',
#  'fp_305.jpg',
#  'fp_463.jpg',
#  'fp_339.jpg',
#  'fp_488.jpg',
#  'fp_113.jpg',
#  'fp_107.jpg',
#  'fp_106.jpg',
#  'fp_112.jpg',
#  'fp_489.jpg',
#  'fp_338.jpg',
#  'fp_304.jpg',
#  'fp_462.jpg',
#  'fp_476.jpg',
#  'fp_310.jpg',
#  'fp_258.jpg',
#  'fp_270.jpg',
#  'fp_264.jpg',
#  'fp_099.jpg',
#  'fp_072.jpg',
#  'fp_066.jpg',
#  'fp_070.jpg',
#  'fp_064.jpg',
#  'fp_058.jpg',
#  'fp_272.jpg',
#  'fp_266.jpg',
#  'fp_500.jpg',
#  'fp_299.jpg',
#  'fp_460.jpg',
#  'fp_306.jpg',
#  'fp_312.jpg',
#  'fp_474.jpg',
#  'fp_448.jpg',
#  'fp_104.jpg',
#  'fp_110.jpg',
#  'fp_138.jpg',
#  'fp_139.jpg',
#  'fp_111.jpg',
#  'fp_105.jpg',
#  'fp_449.jpg',
#  'fp_313.jpg',
#  'fp_475.jpg',
#  'fp_461.jpg',
#  'fp_307.jpg',
#  'fp_298.jpg',
#  'fp_267.jpg',
#  'fp_273.jpg',
#  'fp_059.jpg',
#  'fp_065.jpg',
#  'fp_071.jpg',
#  'fp_049.jpg',
#  'fp_075.jpg',
#  'fp_061.jpg',
#  'fp_277.jpg',
#  'fp_263.jpg',
#  'fp_288.jpg',
#  'fp_459.jpg',
#  'fp_303.jpg',
#  'fp_465.jpg',
#  'fp_471.jpg',
#  'fp_317.jpg',
#  'fp_129.jpg',
#  'fp_101.jpg',
#  'fp_115.jpg',
#  'fp_114.jpg',
#  'fp_100.jpg',
#  'fp_128.jpg',
#  'fp_470.jpg',
#  'fp_316.jpg',
#  'fp_302.jpg',
#  'fp_464.jpg',
#  'fp_458.jpg',
#  'fp_289.jpg',
#  'fp_262.jpg',
#  'fp_276.jpg',
#  'fp_060.jpg',
#  'fp_074.jpg',
#  'fp_048.jpg',
#  'fp_062.jpg',
#  'fp_076.jpg',
#  'fp_089.jpg',
#  'fp_248.jpg',
#  'fp_260.jpg',
#  'fp_274.jpg',
#  'fp_328.jpg',
#  'fp_314.jpg',
#  'fp_472.jpg',
#  'fp_466.jpg',
#  'fp_300.jpg',
#  'fp_499.jpg',
#  'fp_116.jpg',
#  'fp_102.jpg',
#  'fp_103.jpg',
#  'fp_117.jpg',
#  'fp_498.jpg',
#  'fp_467.jpg',
#  'fp_301.jpg',
#  'fp_315.jpg',
#  'fp_473.jpg',
#  'fp_329.jpg',
#  'fp_275.jpg',
#  'fp_261.jpg',
#  'fp_249.jpg',
#  'fp_088.jpg',
#  'fp_077.jpg',
#  'fp_063.jpg',
#  'fp_046.jpg',
#  'fp_052.jpg',
#  'fp_085.jpg',
#  'fp_091.jpg',
#  'fp_244.jpg',
#  'fp_250.jpg',
#  'fp_278.jpg',
#  'fp_287.jpg',
#  'fp_293.jpg',
#  'fp_456.jpg',
#  'fp_330.jpg',
#  'fp_324.jpg',
#  'fp_442.jpg',
#  'fp_318.jpg',
#  'fp_495.jpg',
#  'fp_481.jpg',
#  'fp_132.jpg',
#  'fp_126.jpg',
#  'fp_127.jpg',
#  'fp_133.jpg',
#  'fp_480.jpg',
#  'fp_494.jpg',
#  'fp_319.jpg',
#  'fp_325.jpg',
#  'fp_443.jpg',
#  'fp_457.jpg',
#  'fp_331.jpg',
#  'fp_292.jpg',
#  'fp_286.jpg',
#  'fp_279.jpg',
#  'fp_251.jpg',
#  'fp_245.jpg',
#  'fp_090.jpg',
#  'fp_084.jpg',
#  'fp_053.jpg',
#  'fp_047.jpg',
#  'fp_051.jpg',
#  'fp_045.jpg',
#  'fp_079.jpg',
#  'fp_092.jpg',
#  'fp_086.jpg',
#  'fp_253.jpg',
#  'fp_247.jpg',
#  'fp_290.jpg',
#  'fp_284.jpg',
#  'fp_441.jpg',
#  'fp_327.jpg',
#  'fp_333.jpg',
#  'fp_455.jpg',
#  'fp_469.jpg',
#  'fp_482.jpg',
#  'fp_496.jpg',
#  'fp_125.jpg',
#  'fp_131.jpg',
#  'fp_119.jpg',
#  'fp_118.jpg',
#  'fp_130.jpg',
#  'fp_124.jpg',
#  'fp_497.jpg',
#  'fp_483.jpg',
#  'fp_468.jpg',
#  'fp_332.jpg',
#  'fp_454.jpg',
#  'fp_440.jpg',
#  'fp_326.jpg',
#  'fp_285.jpg',
#  'fp_291.jpg',
#  'fp_246.jpg',
#  'fp_252.jpg',
#  'fp_087.jpg',
#  'fp_093.jpg',
#  'fp_078.jpg',
#  'fp_044.jpg',
#  'fp_050.jpg',
#  'fp_068.jpg',
#  'fp_054.jpg',
#  'fp_040.jpg',
#  'fp_097.jpg',
#  'fp_083.jpg',
#  'fp_256.jpg',
#  'fp_242.jpg',
#  'fp_295.jpg',
#  'fp_281.jpg',
#  'fp_478.jpg',
#  'fp_322.jpg',
#  'fp_444.jpg',
#  'fp_450.jpg',
#  'fp_336.jpg',
#  'fp_487.jpg',
#  'fp_493.jpg',
#  'fp_108.jpg',
#  'fp_120.jpg',
#  'fp_134.jpg',
#  'fp_135.jpg',
#  'fp_121.jpg',
#  'fp_109.jpg',
#  'fp_492.jpg',
#  'fp_486.jpg',
#  'fp_451.jpg',
#  'fp_337.jpg',
#  'fp_323.jpg',
#  'fp_445.jpg',
#  'fp_479.jpg',
#  'fp_280.jpg',
#  'fp_294.jpg',
#  'fp_243.jpg',
#  'fp_257.jpg',
#  'fp_082.jpg',
#  'fp_096.jpg',
#  'fp_041.jpg',
#  'fp_055.jpg',
#  'fp_069.jpg',
#  'fp_043.jpg',
#  'fp_057.jpg',
#  'fp_080.jpg',
#  'fp_094.jpg',
#  'fp_269.jpg',
#  'fp_241.jpg',
#  'fp_255.jpg',
#  'fp_282.jpg',
#  'fp_296.jpg',
#  'fp_309.jpg',
#  'fp_335.jpg',
#  'fp_453.jpg',
#  'fp_447.jpg',
#  'fp_321.jpg',
#  'fp_490.jpg',
#  'fp_484.jpg',
#  'fp_137.jpg',
#  'fp_123.jpg',
#  'fp_122.jpg',
#  'fp_136.jpg',
#  'fp_485.jpg',
#  'fp_491.jpg',
#  'fp_446.jpg',
#  'fp_320.jpg',
#  'fp_334.jpg',
#  'fp_452.jpg',
#  'fp_308.jpg',
#  'fp_297.jpg',
#  'fp_283.jpg',
#  'fp_254.jpg',
#  'fp_240.jpg',
#  'fp_268.jpg',
#  'fp_095.jpg',
#  'fp_081.jpg',
#  'fp_056.jpg',
#  'fp_042.jpg',
#  'fp_025.jpg',
#  'fp_031.jpg',
#  'fp_019.jpg',
#  'fp_227.jpg',
#  'fp_233.jpg',
#  'fp_353.jpg',
#  'fp_435.jpg',
#  'fp_421.jpg',
#  'fp_347.jpg',
#  'fp_409.jpg',
#  'fp_390.jpg',
#  'fp_384.jpg',
#  'fp_151.jpg',
#  'fp_145.jpg',
#  'fp_179.jpg',
#  'fp_192.jpg',
#  'fp_186.jpg',
#  'fp_187.jpg',
#  'fp_193.jpg',
#  'fp_178.jpg',
#  'fp_144.jpg',
#  'fp_150.jpg',
#  'fp_385.jpg',
#  'fp_391.jpg',
#  'fp_408.jpg',
#  'fp_420.jpg',
#  'fp_346.jpg',
#  'fp_352.jpg',
#  'fp_434.jpg',
#  'fp_232.jpg',
#  'fp_226.jpg',
#  'fp_018.jpg',
#  'fp_030.jpg',
#  'fp_024.jpg',
#  'fp_032.jpg',
#  'fp_026.jpg',
#  'fp_230.jpg',
#  'fp_224.jpg',
#  'fp_218.jpg',
#  'fp_344.jpg',
#  'fp_422.jpg',
#  'fp_436.jpg',
#  'fp_350.jpg',
#  'fp_378.jpg',
#  'fp_387.jpg',
#  'fp_393.jpg',
#  'fp_146.jpg',
#  'fp_152.jpg',
#  'fp_185.jpg',
#  'fp_191.jpg',
#  'fp_190.jpg',
#  'fp_184.jpg',
#  'fp_153.jpg',
#  'fp_147.jpg',
#  'fp_392.jpg',
#  'fp_386.jpg',
#  'fp_379.jpg',
#  'fp_437.jpg',
#  'fp_351.jpg',
#  'fp_345.jpg',
#  'fp_423.jpg',
#  'fp_219.jpg',
#  'fp_225.jpg',
#  'fp_231.jpg',
#  'fp_027.jpg',
#  'fp_033.jpg',
#  'fp_037.jpg',
#  'fp_023.jpg',
#  'fp_209.jpg',
#  'fp_235.jpg',
#  'fp_221.jpg',
#  'fp_369.jpg',
#  'fp_427.jpg',
#  'fp_341.jpg',
#  'fp_355.jpg',
#  'fp_433.jpg',
#  'fp_382.jpg',
#  'fp_396.jpg',
#  'fp_143.jpg',
#  'fp_157.jpg',
#  'fp_180.jpg',
#  'fp_194.jpg',
#  'fp_195.jpg',
#  'fp_181.jpg',
#  'fp_156.jpg',
#  'fp_142.jpg',
#  'fp_397.jpg',
#  'fp_383.jpg',
#  'fp_354.jpg',
#  'fp_432.jpg',
#  'fp_426.jpg',
#  'fp_340.jpg',
#  'fp_368.jpg',
#  'fp_220.jpg',
#  'fp_234.jpg',
#  'fp_208.jpg',
#  'fp_022.jpg',
#  'fp_036.jpg',
#  'fp_008.jpg',
#  'fp_020.jpg',
#  'fp_034.jpg',
#  'fp_222.jpg',
#  'fp_236.jpg',
#  'fp_418.jpg',
#  'fp_430.jpg',
#  'fp_356.jpg',
#  'fp_342.jpg',
#  'fp_424.jpg',
#  'fp_395.jpg',
#  'fp_381.jpg',
#  'fp_168.jpg',
#  'fp_154.jpg',
#  'fp_140.jpg',
#  'fp_197.jpg',
#  'fp_183.jpg',
#  'fp_182.jpg',
#  'fp_196.jpg',
#  'fp_141.jpg',
#  'fp_155.jpg',
#  'fp_169.jpg',
#  'fp_380.jpg',
#  'fp_394.jpg',
#  'fp_343.jpg',
#  'fp_425.jpg',
#  'fp_431.jpg',
#  'fp_357.jpg',
#  'fp_419.jpg',
#  'fp_237.jpg',
#  'fp_223.jpg',
#  'fp_035.jpg',
#  'fp_021.jpg',
#  'fp_009.jpg']

# %%
#파일 목록 정렬해서 리스트에 다시 저장하기 
file_list_sorted = sorted(file_list)

# %%
import csv
import numpy as np 

# numpy array로 바꿔서 shape 바꾸기 
np_array = np.array(file_list_sorted)
np_array = np_array.reshape(len(np_array),-1)
np_array

# numpy array 한 줄씩 csv에 저장하기 
f = open('labeling.csv','w')
wr =  csv.writer(f)

for i in np_array:
    wr.writerow(i)
f.close()

# %%
from PIL import Image
